# %%
import pandas as pd

# %%
data={
    'apples':[3,1,9,6],
    'oranges':[1,2,5,3]
}

# %%
data
# Out:
# {'apples': [3, 1, 9, 6], 'oranges': [1, 2, 5, 3]}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#    apples  oranges
# 0       3        1
# 1       1        2
# 2       9        5
# 3       6        3

# %%
df=pd.DataFrame(data,index=['june','july','may','aug'])

# %%
df
# Out:
#       apples  oranges
# june       3        1
# july       1        2
# may        9        5
# aug        6        3

# %%
df.loc['june']
# Out:
# apples     3
# oranges    1
# Name: june, dtype: int64

# %%
df=pd.read_csv('purchases.csv')

# %%
df
# Out:
#   Unnamed: 0  apples  oranges
# 0       June       3        0
# 1     Robert       2        3
# 2       Lily       0        7
# 3      David       1        2

# %%
df=pd.read_csv('purchases.csv',index_col=0)

# %%
df
# Out:
#         apples  oranges
# June         3        0
# Robert       2        3
# Lily         0        7
# David        1        2

# %%
df=pd.read_json('purchases.json')

# %%
df
# Out:
#         apples  oranges
# David        1        2
# June         3        0
# Lily         0        7
# Robert       2        3

# %%
import sqlite3
con=sqlite3.connect("database.db")

# %%
df=pd.read_sql_query("select *from purchases",con)

# %%
df
# Out:
#     index  apples  oranges
# 0    June       3        0
# 1  Robert       2        3
# 2    Lily       0        7
# 3   David       1        2

# %%
df=df.set_index('index')

# %%
df
# Out:
#         apples  oranges
# index
# June         3        0
# Robert       2        3
# Lily         0        7
# David        1        2

# %%
#df.to_csv("new_csv")

# %%
mdf=pd.read_csv('IMDB-Movie-Data.csv',index_col=0)

# %%
mdf
# Out:
#                                         Title                       Genre  \
# Rank
# 1                     Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 2                                  Prometheus    Adventure,Mystery,Sci-Fi
# 3                                       Split             Horror,Thriller
# 4                                        Sing     Animation,Comedy,Family
# 5                               Suicide Squad    Action,Adventure,Fantasy
# 6                              The Great Wall    Action,Adventure,Fantasy
# 7                                  La La Land          Comedy,Drama,Music
# 8                                    Mindhorn                      Comedy
# 9                          The Lost City of Z  Action,Adventure,Biography
# 10                                 Passengers     Adventure,Drama,Romance
# 11    Fantastic Beasts and Where to Find Them    Adventure,Family,Fantasy
# 12                             Hidden Figures     Biography,Drama,History
# 13                                  Rogue One     Action,Adventure,Sci-Fi
# 14                                      Moana  Animation,Adventure,Comedy
# 15                                   Colossal         Action,Comedy,Drama
# 16                    The Secret Life of Pets  Animation,Adventure,Comedy
# 17                              Hacksaw Ridge     Biography,Drama,History
# 18                               Jason Bourne             Action,Thriller
# 19                                       Lion             Biography,Drama
# 20                                    Arrival        Drama,Mystery,Sci-Fi
# 21                                       Gold    Adventure,Drama,Thriller
# 22                      Manchester by the Sea                       Drama
# 23                             Hounds of Love          Crime,Drama,Horror
# 24                                     Trolls  Animation,Adventure,Comedy
# 25               Independence Day: Resurgence     Action,Adventure,Sci-Fi
# 26                            Paris pieds nus                      Comedy
# 27                    Bahubali: The Beginning      Action,Adventure,Drama
# 28                                 Dead Awake             Horror,Thriller
# 29                                   Bad Moms                      Comedy
# 30                           Assassin's Creed      Action,Adventure,Drama
# ...                                       ...                         ...
# 971                         Texas Chainsaw 3D             Horror,Thriller
# 972                                 Disturbia      Drama,Mystery,Thriller
# 973                              Rock of Ages        Comedy,Drama,Musical
# 974                                  Scream 4              Horror,Mystery
# 975                            Queen of Katwe       Biography,Drama,Sport
# 976                My Big Fat Greek Wedding 2       Comedy,Family,Romance
# 977                               Dark Places      Drama,Mystery,Thriller
# 978                             Amateur Night                      Comedy
# 979            It's Only the End of the World                       Drama
# 980                        The Skin I Live In              Drama,Thriller
# 981                      Miracles from Heaven      Biography,Drama,Family
# 982                                     Annie         Comedy,Drama,Family
# 983                       Across the Universe       Drama,Fantasy,Musical
# 984                             Let's Be Cops                      Comedy
# 985                                       Max            Adventure,Family
# 986                             Your Highness    Adventure,Comedy,Fantasy
# 987                       Final Destination 5             Horror,Thriller
# 988                              Endless Love               Drama,Romance
# 989                                   Martyrs                      Horror
# 990                                     Selma     Biography,Drama,History
# 991            Underworld: Rise of the Lycans    Action,Adventure,Fantasy
# 992                          Taare Zameen Par          Drama,Family,Music
# 993                      Take Me Home Tonight        Comedy,Drama,Romance
# 994                  Resident Evil: Afterlife     Action,Adventure,Horror
# 995                                 Project X                      Comedy
# 996                      Secret in Their Eyes         Crime,Drama,Mystery
# 997                           Hostel: Part II                      Horror
# 998                    Step Up 2: The Streets         Drama,Music,Romance
# 999                              Search Party            Adventure,Comedy
# 1000                               Nine Lives       Comedy,Family,Fantasy
#
#                                             Description  \
# Rank
# 1     A group of intergalactic criminals are forced ...
# 2     Following clues to the origin of mankind, a te...
# 3     Three girls are kidnapped by a man with a diag...
# 4     In a city of humanoid animals, a hustling thea...
# 5     A secret government agency recruits some of th...
# 6     European mercenaries searching for black powde...
# 7     A jazz pianist falls for an aspiring actress i...
# 8     A has-been actor best known for playing the ti...
# 9     A true-life drama, centering on British explor...
# 10    A spacecraft traveling to a distant colony pla...
# 11    The adventures of writer Newt Scamander in New...
# 12    The story of a team of female African-American...
# 13    The Rebel Alliance makes a risky move to steal...
# 14    In Ancient Polynesia, when a terrible curse in...
# 15    Gloria is an out-of-work party girl forced to ...
# 16    The quiet life of a terrier named Max is upend...
# 17    WWII American Army Medic Desmond T. Doss, who ...
# 18    The CIA's most dangerous former operative is d...
# 19    A five-year-old Indian boy gets lost on the st...
# 20    When twelve mysterious spacecraft appear aroun...
# 21    Kenny Wells, a prospector desperate for a luck...
# 22    A depressed uncle is asked to take care of his...
# 23    A cold-blooded predatory couple while cruising...
# 24    After the Bergens invade Troll Village, Poppy,...
# 25    Two decades after the first Independence Day i...
# 26    Fiona visits Paris for the first time to assis...
# 27    In ancient India, an adventurous and daring ma...
# 28    A young woman must save herself and her friend...
# 29    When three overworked and under-appreciated mo...
# 30    When Callum Lynch explores the memories of his...
# ...                                                 ...
# 971   A young woman travels to Texas to collect an i...
# 972   A teen living under house arrest becomes convi...
# 973   A small town girl and a city boy meet on the S...
# 974   Ten years have passed, and Sidney Prescott, wh...
# 975   A Ugandan girl sees her world rapidly change a...
# 976   A Portokalos family secret brings the beloved ...
# 977   Libby Day was only eight years old when her fa...
# 978   Guy Carter is an award-winning graduate studen...
# 979   Louis (Gaspard Ulliel), a terminally ill write...
# 980   A brilliant plastic surgeon, haunted by past t...
# 981   A young girl suffering from a rare digestive d...
# 982   A foster kid, who lives with her mean foster m...
# 983   The music of the Beatles and the Vietnam War f...
# 984   Two struggling pals dress as police officers f...
# 985   A Malinois dog that helped American Marines in...
# 986   When Prince Fabious's bride is kidnapped, he g...
# 987   Survivors of a suspension-bridge collapse lear...
# 988   The story of a privileged girl and a charismat...
# 989   A young woman's quest for revenge against the ...
# 990   A chronicle of Martin Luther King's campaign t...
# 991   An origins story centered on the centuries-old...
# 992   An eight-year-old boy is thought to be a lazy ...
# 993   Four years after graduation, an awkward high s...
# 994   While still out to destroy the evil Umbrella C...
# 995   3 high school seniors throw a birthday party t...
# 996   A tight-knit team of rising investigators, alo...
# 997   Three American college students studying abroa...
# 998   Romantic sparks occur between two dance studen...
# 999   A pair of friends embark on a mission to reuni...
# 1000  A stuffy businessman finds himself trapped ins...
#
#                    Director  \
# Rank
# 1                James Gunn
# 2              Ridley Scott
# 3        M. Night Shyamalan
# 4      Christophe Lourdelet
# 5                David Ayer
# 6               Yimou Zhang
# 7           Damien Chazelle
# 8                Sean Foley
# 9                James Gray
# 10            Morten Tyldum
# 11              David Yates
# 12           Theodore Melfi
# 13           Gareth Edwards
# 14             Ron Clements
# 15          Nacho Vigalondo
# 16             Chris Renaud
# 17               Mel Gibson
# 18          Paul Greengrass
# 19              Garth Davis
# 20         Denis Villeneuve
# 21           Stephen Gaghan
# 22         Kenneth Lonergan
# 23                Ben Young
# 24               Walt Dohrn
# 25          Roland Emmerich
# 26           Dominique Abel
# 27           S.S. Rajamouli
# 28           Phillip Guzman
# 29                Jon Lucas
# 30            Justin Kurzel
# ...                     ...
# 971         John Luessenhop
# 972             D.J. Caruso
# 973           Adam Shankman
# 974              Wes Craven
# 975               Mira Nair
# 976              Kirk Jones
# 977   Gilles Paquet-Brenner
# 978            Lisa Addario
# 979            Xavier Dolan
# 980         Pedro Almodóvar
# 981         Patricia Riggen
# 982              Will Gluck
# 983            Julie Taymor
# 984         Luke Greenfield
# 985              Boaz Yakin
# 986      David Gordon Green
# 987            Steven Quale
# 988             Shana Feste
# 989          Pascal Laugier
# 990            Ava DuVernay
# 991      Patrick Tatopoulos
# 992              Aamir Khan
# 993           Michael Dowse
# 994      Paul W.S. Anderson
# 995         Nima Nourizadeh
# 996               Billy Ray
# 997                Eli Roth
# 998              Jon M. Chu
# 999          Scot Armstrong
# 1000       Barry Sonnenfeld
#
#                                                  Actors  Year  \
# Rank
# 1     Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S
# 26                   83     6.8     222                 NaN        NaN
# 27                  159     8.3   76193                6.50        NaN
# 28                   99     4.7     523                0.01        NaN
# 29                  100     6.2   66540              113.08       60.0
# 30                  115     5.9  112813               54.65       36.0
# ...                 ...     ...     ...                 ...        ...
# 971                  92     4.8   37060               34.33       62.0
# 972                 105     6.9  193491               80.05        NaN
# 973                 123     5.9   64513               38.51       47.0
# 974                 111     6.2  108544               38.18       52.0
# 975                 124     7.4    6753                8.81       73.0
# 976                  94     6.0   20966               59.57       37.0
# 977                 113     6.2   31634                 NaN       39.0
# 978                  92     5.0    2229                 NaN       38.0
# 979                  97     7.0   10658                 NaN       48.0
# 980                 120     7.6  108772                3.19       70.0
# 981                 109     7.0   12048               61.69       44.0
# 982                 118     5.3   27312               85.91       33.0
# 983                 133     7.4   95172               24.34       56.0
# 984                 104     6.5  112729               82.39       30.0
# 985                 111     6.8   21405               42.65       47.0
# 986                 102     5.6   87904               21.56       31.0
# 987                  92     5.9   88000               42.58       50.0
# 988                 104     6.3   33688               23.39       30.0
# 989                  99     7.1   63785                 NaN       89.0
# 990                 128     7.5   67637               52.07        NaN
# 991                  92     6.6  129708               45.80       44.0
# 992                 165     8.5  102697                1.20       42.0
# 993                  97     6.3   45419                6.92        NaN
# 994                  97     5.9  140900               60.13       37.0
# 995                  88     6.7  164088               54.72       48.0
# 996                 111     6.2   27585                 NaN       45.0
# 997                  94     5.5   73152               17.54       46.0
# 998                  98     6.2   70699               58.01       50.0
# 999                  93     5.6    4881                 NaN       22.0
# 1000                 87     5.3   12435               19.64       11.0
#
# [1000 rows x 11 columns]

# %%
mdf.head()
# Out:
#                         Title                     Genre  \
# Rank
# 1     Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 2                  Prometheus  Adventure,Mystery,Sci-Fi
# 3                       Split           Horror,Thriller
# 4                        Sing   Animation,Comedy,Family
# 5               Suicide Squad  Action,Adventure,Fantasy
#
#                                             Description              Director  \
# Rank
# 1     A group of intergalactic criminals are forced ...            James Gunn
# 2     Following clues to the origin of mankind, a te...          Ridley Scott
# 3     Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 4     In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 5     A secret government agency recruits some of th...            David Ayer
#
#                                                  Actors  Year  \
# Rank
# 1     Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014
# 2     Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012
# 3     James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016
# 4     Matthew McConaughey,Reese Witherspoon, Seth Ma...  2016
# 5     Will Smith, Jared Leto, Margot Robbie, Viola D...  2016
#
#       Runtime (Minutes)  Rating   Votes  Revenue (Millions)  Metascore
# Rank
# 1                   121     8.1  757074              333.13       76.0
# 2                   124     7.0  485820              126.46       65.0
# 3                   117     7.3  157606              138.12       62.0
# 4                   108     7.2   60545              270.32       59.0
# 5                   123     6.2  393727              325.02       40.0

# %%
mdf.tail(2)
# Out:
#              Title                  Genre  \
# Rank
# 999   Search Party       Adventure,Comedy
# 1000    Nine Lives  Comedy,Family,Fantasy
#
#                                             Description          Director  \
# Rank
# 999   A pair of friends embark on a mission to reuni...    Scot Armstrong
# 1000  A stuffy businessman finds himself trapped ins...  Barry Sonnenfeld
#
#                                                  Actors  Year  \
# Rank
# 999   Adam Pally, T.J. Miller, Thomas Middleditch,Sh...  2014
# 1000  Kevin Spacey, Jennifer Garner, Robbie Amell,Ch...  2016
#
#       Runtime (Minutes)  Rating  Votes  Revenue (Millions)  Metascore
# Rank
# 999                  93     5.6   4881                 NaN       22.0
# 1000                 87     5.3  12435               19.64       11.0

# %%
mdf.describe()
# Out:
#               Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean   2012.783000         113.172000     6.723200  1.698083e+05
# std       3.205962          18.810908     0.945429  1.887626e+05
# min    2006.000000          66.000000     1.900000  6.100000e+01
# 25%    2010.000000         100.000000     6.200000  3.630900e+04
# 50%    2014.000000         111.000000     6.800000  1.107990e+05
# 75%    2016.000000         123.000000     7.400000  2.399098e+05
# max    2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# 50%             47.985000   59.500000
# 75%            113.715000   72.000000
# max            936.630000  100.000000

# %%
mdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 1 to 1000
# Data columns (total 11 columns):
# Title                 1000 non-null object
# Genre                 1000 non-null object
# Description           1000 non-null object
# Director              1000 non-null object
# Actors                1000 non-null object
# Year                  1000 non-null int64
# Runtime (Minutes)     1000 non-null int64
# Rating                1000 non-null float64
# Votes                 1000 non-null int64
# Revenue (Millions)    872 non-null float64
# Metascore             936 non-null float64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 93.8+ KB

# %%
mdf.shape
# Out:
# (1000, 11)

# %%
tdf=mdf.append(mdf)

# %%
tdf.shape
# Out:
# (2000, 11)

# %%
#tdf=tdf.drop_duplicates()

# %%
#tdf.shape

# %%
tdf.drop_duplicates(inplace=True, keep=False)

# %%
tdf.shape
# Out:
# (0, 11)

# %%
mdf.columns
# Out:
# Index(['Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
mdf.rename(columns={
    'Runtime (Minutes)':'runtime',
    'Revenue (Millions)':'revenue'
     },inplace=True)
mdf.columns
# Out:
# Index(['Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'runtime', 'Rating', 'Votes', 'revenue', 'Metascore'],
#       dtype='object')

# %%
mdf.columns=[col.lower() for col in mdf]
